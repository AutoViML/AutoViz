# %%
import pandas as pd
import sys
sys.path.append('../ram_code/')
import AutoViz_Class as AV
# Out:
# Imported AutoViz_Class. Call by using AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)

# %%
AVC = AV.AutoViz_Class()

# %%
datapath = '../data_sets/'
#filename = 'iris2.csv'
filename = 'boston.csv'
#filename = 'creditcard_fraud.csv' ## awesome example of how to interpret variables for fraud
sep = '\t'
target = 'MEDV'

# %%
df = pd.read_csv(datapath+filename,sep=sep,index_col=None)
print(df.shape)
df.head(1)
# Out:
# (506, 14)
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE   DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.09    1  296     15.3
#
#        B  LSTAT  MEDV
# 0  396.9   4.98  24.0

# %%
dft = AVC.AutoViz('', sep, target, df, header=0, verbose=0,
                            lowess=False,chart_format='svg',max_rows_analyzed=150000,
                                max_cols_analyzed=30)
# Out:
# Shape of your Data Set: (506, 14)
# Classifying variables in data set...
#     13 Predictors classified...
#         This does not include the Target column(s)
#     No variables removed since no ID or low-information variables found in data set
# Number of All Scatter Plots = 55
# All Plots done
# Time to run AutoViz (in seconds) = 4.476
